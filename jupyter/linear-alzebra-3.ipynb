# %%
import numpy as np

# %%
x=np.array([1,2,3])
x.shape
# Out:
# (3,)

# %%
y=np.array([[1,2,3],[4,5,6]])

# %%
y.shape
# Out:
# (2, 3)

# %%
z=np.array([[1,2],[3,4],[6,7]])

# %%
z.shape
# Out:
# (3, 2)

# %%
print(y)
np.transpose(y)
# Out:
# [[1 2 3]
#  [4 5 6]]
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
A=np.array([[1,2,3],[4,6,9],[6,7,8]])
B=np.array([[4,6,1],[9,7,8],[1,2,3]])
print(A*B) # ELEMENT X ELEMENT 
print("----------------------------")
print(np.matmul(A,B)) # MATRIX MULTIPLICATION
# Out:
# [[ 4 12  3]
#  [36 42 72]
#  [ 6 14 24]]
# ----------------------------
# [[ 25  26  26]
#  [ 79  84  79]
#  [ 95 101  86]]

# %%
np.exp(x) #exponential graph mapped with the passed areay
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
a=np.array([0,0.5,1,1.5,2,2.5,2])

# %%
result=np.exp(a);

# %%
print(result)
# Out:
# [ 1.          1.64872127  2.71828183  4.48168907  7.3890561  12.18249396
#   7.3890561 ]

# %%
np.sin(a)
# Out:
# array([0.        , 0.47942554, 0.84147098, 0.99749499, 0.90929743,
#        0.59847214, 0.90929743])

# %%
np.tanh(a) #hyperbolic func
# Out:
# array([0.        , 0.46211716, 0.76159416, 0.90514825, 0.96402758,
#        0.9866143 , 0.96402758])

# %%
def operation(h,w):
    A=np.random.random([h,w])
    B=np.random.random([h,w])
    s=A+B

    return (A,B,s)
operation(3,3)
# Out:
# (array([[0.54596232, 0.17559118, 0.25562211],
#         [0.500309  , 0.32723951, 0.43888255],
#         [0.69533427, 0.04872241, 0.74204651]]),
#  array([[0.11389717, 0.33303869, 0.59038835],
#         [0.36890604, 0.53359853, 0.81579476],
#         [0.77384828, 0.57234042, 0.11388965]]),
#  array([[0.65985949, 0.50862987, 0.84601046],
#         [0.86921504, 0.86083804, 1.25467731],
#         [1.46918255, 0.62106283, 0.85593616]]))

# %%
np.random.random([3,3])
# Out:
# array([[0.65487241, 0.29032292, 0.59414975],
#        [0.79626263, 0.5999804 , 0.58205879],
#        [0.18456719, 0.6761018 , 0.8181503 ]])

# %%
print(a) #max and min
print(np.max(a))
a.max()
# Out:
# [0.  0.5 1.  1.5 2.  2.5 2. ]
# 2.5
# 2.5

# %%
np.random.random() #random between 0 to 1
# Out:
# 0.6757757600781691

# %%
np.random.random([2,10]) #random array
# Out:
# array([[3.16659469e-04, 3.65661151e-01, 8.07973309e-01, 3.93348684e-01,
#         3.38559530e-01, 1.95818561e-01, 6.97025551e-01, 5.75600250e-02,
#         2.34098816e-01, 4.08111843e-02],
#        [2.94251833e-01, 8.64896564e-01, 9.88896507e-02, 2.43305830e-02,
#         5.89564791e-01, 9.91042877e-01, 3.16121559e-01, 2.81114709e-01,
#         1.77894195e-01, 2.28272773e-01]])

# %%
np.linalg.norm(a) #normal of matrix
# Out:
# 4.2130748865881795

# %%
A=np.array([1,2,3,4,5])
B=np.array([7,8,9,0,6])
def func(A,B):
    sum=A+B
    return np.linalg.norm(sum)

func(A,B)
# Out:
# 21.095023109728988
